# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot

# %%
path = "./dataset/images/simplot_14_rgb.tiff"

# %%
image = Image.open(path)

# %%
image
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGBA size=200x200 at 0x11911E080>

# %%
npmg = np.asarray(Image.open("./dataset/images/simplot_14_rgb.tiff"))
pyplot.imshow(npmg[:,:,np.arange(3)])
npmg[:,:,np.arange(3)].shape
# Out:
# (200, 199, 3)

# %%
print(imgt.shape)
imgt = npmg[:, :, ::-1]
pyplot.imshow(imgt)

path = '/Users/sergiomarconi/Documents/simplot_14.tif'
# Out:
# (200, 200, 4)

# %%
import rasterio
with rasterio.open(path, 'r') as ds:
    arr = ds.read()  # read all raster values

# %%
print(arr.shape)
arr = np.swapaxes(arr,0,1)
arr = np.swapaxes(arr,1,2)

print(arr.shape)
pyplot.imshow(arr[:, :, ::-1])
# Out:
# (4, 200, 199)
# (200, 199, 4)
